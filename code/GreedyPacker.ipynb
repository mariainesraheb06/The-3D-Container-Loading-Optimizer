# %% [markdown]
# • Greedy Heuristic (Best-Fit Decreasing):
# o Sort boxes by volume (largest first). Place each box in the first available space that fits.

# %%
def GreedyPacker():


    start_time = time.time()
